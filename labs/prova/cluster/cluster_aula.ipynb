# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
import numpy as np

# %%
n_samples = 50000
n_clusters = 3

centers = np.array([[0, 0], [5, 5], [10, 10]])

X, y = make_blobs(n_samples=n_samples, centers=centers, random_state=42)
kmeans = KMeans(n_clusters=n_clusters)
kmeans.fit(X)

plt.scatter(X[:, 0], X[:, 1], c=kmeans.labels_)
# Out:
# c:\Users\eduya\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
X[:, 0] = X[:, 0] * 100
X[:, 1] = X[:, 1] / 100

plt.scatter(X[:, 0], X[:, 1], c=kmeans.labels_)

# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd

# %%
dta  = fetch_california_housing()

# %%
df  = pd.DataFrame(dta.data, columns=dta.feature_names)

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
X = df[["Latitude", "Longitude"]].values
plt.scatter(X[:, 0], X[:, 1])

# %%
kmeans = KMeans(n_clusters=15, random_state=42)
kmeans.fit(X)
# Out:
# c:\Users\eduya\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\eduya\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# found 0 physical cores < 1
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\eduya\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\externals\loky\backend\context.py", line 282, in _count_physical_cores
#     raise ValueError(f"found {cpu_count_physical} physical cores < 1")
# KMeans(n_clusters=15, random_state=42)

# %%
plt.scatter(X[:, 0], X[:, 1], c=kmeans.labels_)
